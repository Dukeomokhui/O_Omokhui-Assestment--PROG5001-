# %% [markdown]
# <a href="https://colab.research.google.com/github/Dukeomokhui/O_Omokhui-Assestment--PROG5001-/blob/main/Week_1_Blockchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import hashlib
import time
import datetime

# %% [markdown]
# "get data seperated with - sign"

# %%
def get_hash(transaction_list):
  return "_". join(transaction_list)

# create a hash value of any data
def get_hash(data):
  return hashlib.sha256(data.encode)
